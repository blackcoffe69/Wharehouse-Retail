# %%
import pandas as pd
Ware_house=pd.read_csv("Warehouse_and_Retail_Sales.csv")

# %%
Ware_house
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
Head_ware_house=Ware_house.head(5)
Tail_ware_house=Ware_house.tail(5)
print(Head_ware_house)
print(Tail_ware_house)
# Head_whare_hous this is to display first 5 rows
# Tail_whare_house this is to display 5 last rows
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %% [markdown]
# # Analysing the data trend for highest performing store by product by month,the total revenue generated on each product

# %%
check_empty_cells = Ware_house[["YEAR","MONTH","SUPPLIER","ITEM CODE","ITEM DESCRIPTION","ITEM TYPE","RETAIL SALES","RETAIL TRANSFERS","WAREHOUSE SALES"]].isnull

check_empty_cells
# this is to check for empty cells within the columns
# Out:
# <bound method DataFrame.isnull of         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# ...

# %%
Ware_house["SUPPLIER"].fillna(0, inplace=True)
Ware_house
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
Ware_house["RETAIL SALES"].fillna(0, inplace=True)
Ware_house
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
Ware_house.dtypes
# this is to check the types of variables in each columnsb
# Out:
# YEAR                  int64
# MONTH                 int64
# SUPPLIER             object
# ITEM CODE            object
# ITEM DESCRIPTION     object
# ITEM TYPE            object
# RETAIL SALES        float64
# RETAIL TRANSFERS    float64
# WAREHOUSE SALES     float64
# dtype: object

# %%
Ware_house.duplicated()
# this is to check for duplicate values within the dataframe
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307640    False
# 307641    False
# 307642    False
# 307643    False
# 307644    False
# Length: 307645, dtype: bool

# %% [markdown]
# # Checking through to see the values of each column and rows

# %%
Ware_house.describe()
# this shows the the count for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the Mean for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the Std for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the Min for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the 25% for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the 50% for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the 75% for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# this shows the the Max for Year,Month,Retail Sales,Retail Transfers,Wharehouse Sales
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307645.000000     307645.000000
# mean     2018.438525       6.423862       7.024003          6.936465
# std         1.083061       3.461812      30.986095         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.260000          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
Ware_house["ITEM TYPE"].count()
# this to show the total number of items
# Out:
# 307644

# %%
Itemtype_counts=Ware_house["ITEM TYPE"].value_counts()
Itemtype_counts
# this is to show the list and total number of each items
# Out:
# ITEM TYPE
# WINE            187640
# LIQUOR           64910
# BEER             42413
# KEGS             10146
# NON-ALCOHOL       1908
# STR_SUPPLIES       405
# REF                127
# DUNNAGE             95
# Name: count, dtype: int64

# %% [markdown]
# # Analyzing the value count of each section using bar chart

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
sales_by_month = Ware_house.groupby("MONTH")["WAREHOUSE SALES"].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=sales_by_month, x="MONTH", y="WAREHOUSE SALES", marker='o', color='blue')
# Out:
# <Axes: xlabel='MONTH', ylabel='WAREHOUSE SALES'>

# %%
print(sales_by_month)
# month 7 shows the highest Wharehouse sales of 1109919.19 sales
# the plot shows month 12 with the lowest sales 306957.22 sales
# Out:
#     MONTH  WAREHOUSE SALES
# 0       1        819013.63
# 1       2        513596.20
# 2       3        610713.70
# 3       4        298840.87
# 4       5        383791.58
# 5       6        725977.91
# 6       7       1109919.19
# 7       8        731789.78
# 8       9        988834.16
# 9      10        653917.94
# 10     11        638404.10
# 11     12        306957.22

# %%
sales_pivot = Ware_house.pivot_table(index='YEAR', columns='ITEM TYPE', aggfunc='size', fill_value=0)

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=sales_pivot.stack().reset_index(), x='YEAR', y=0, hue='ITEM TYPE', palette='muted', ci=None)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales by Year and Item Type')
plt.legend(title='Item Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Biodun\AppData\Local\Temp\ipykernel_21584\2295699453.py:2: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
print(sales_pivot)
# Out:
# ITEM TYPE   BEER  DUNNAGE  KEGS  LIQUOR  NON-ALCOHOL  REF  STR_SUPPLIES   WINE
# YEAR
# 2017       12312       28  3226   20718          496   43            88  59372
# 2018        3451        8   848    5952          150   12            21  16003
# 2019       19787       44  4822   28538          907   60           209  84271
# 2020        6863       15  1250    9702          355   12            87  27994

# %% [markdown]
# # Aggregating Supplier value count

# %%
supplier_counts = Ware_house["SUPPLIER"].value_counts().reset_index()
supplier_counts.columns = ["SUPPLIER", "Count"]
top_50_suppliers = supplier_counts.head(50)
# getting the first (50) supplies to show only because the number of suppliers exceed what the bar chart can contain

# %%
plt.figure(figsize = (9, 8))
sns.barplot(data = top_50_suppliers, x = "Count", y = "SUPPLIER")
plt.title("SUPPLIER BY COUNT")
plt.xlabel("Count")
plt.ylabel("SUPPLIER")
plt.tight_layout()
plt.show()

# %%
print(top_50_suppliers)
# Out:
#                                   SUPPLIER  Count
# 0        REPUBLIC NATIONAL DISTRIBUTING CO  20995
# 1                              LEGENDS LTD  13634
# 2        SOUTHERN GLAZERS WINE AND SPIRITS  11720
# 3                       E & J GALLO WINERY  10816
# 4     THE COUNTRY VINTNER, LLC DBA WINEBOW  10669
# 5                MONSIEUR TOUTON SELECTION  10360
# 6                    A VINTNERS SELECTIONS   9994
# 7                    BACCHUS IMPORTERS LTD   9150
# 8                 DIAGEO NORTH AMERICA INC   7520
# 9                  RELIABLE CHURCHILL LLLP   6971
# 10                    CONSTELLATION BRANDS   6684
# 11                      JIM BEAM BRANDS CO   5993
# 12                      ANHEUSER BUSCH INC   5835
# 13                                DOPS INC   5265
# 14                   PERNOD RICARD USA LLC   5141
# 15       PRESTIGE BEVERAGE GROUP OF MD LLC   5100
# 16         OPICI FAMILY DISTRIBUTING OF MD   4997
# 17                   CONSTANTINE WINES INC   4932
# ...

# %% [markdown]
# # Aggregating the Warehouse sales per year

# %%
WS = Ware_house.sort_values("WAREHOUSE SALES").reset_index(drop = True)

# %%
WS
# Out:
#         YEAR  MONTH                  SUPPLIER ITEM CODE  \
# 0       2019      8                         0       600
# 1       2017     10        ANHEUSER BUSCH INC       175
# 2       2017      6        ANHEUSER BUSCH INC       175
# 3       2017      8        ANHEUSER BUSCH INC       175
# 4       2019     10  PREMIUM DISTRIBUTORS INC       175
# ...      ...    ...                       ...       ...
# 307640  2017      6             CROWN IMPORTS     96750
# 307641  2017     11             CROWN IMPORTS     23445
# 307642  2019      5             CROWN IMPORTS     23445
# 307643  2019      7             CROWN IMPORTS     23445
# 307644  2020      7             CROWN IMPORTS     23445
#
#                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0           ISTORE TRAINING OVERVIEW       REF           0.0
# 1              EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0
# 2              EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0
# ...

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.lineplot(data=WS, x = "YEAR", y = "ITEM TYPE", marker = "o")
plt.title("ITEM TYPE by Year")
plt.xlabel("YEAR")
plt.ylabel("ITEM TYPE")
plt.xticks(Ware_house["YEAR"])
plt.tight_layout()
plt.show()

# %%
print(WS)
# It shows that their was reduction in sales in 2018
# The increase in sales starts to show after then with the peek period till 2020
# Out:
#         YEAR  MONTH                  SUPPLIER ITEM CODE  \
# 0       2019      8                         0       600
# 1       2017     10        ANHEUSER BUSCH INC       175
# 2       2017      6        ANHEUSER BUSCH INC       175
# 3       2017      8        ANHEUSER BUSCH INC       175
# 4       2019     10  PREMIUM DISTRIBUTORS INC       175
# ...      ...    ...                       ...       ...
# 307640  2017      6             CROWN IMPORTS     96750
# 307641  2017     11             CROWN IMPORTS     23445
# 307642  2019      5             CROWN IMPORTS     23445
# 307643  2019      7             CROWN IMPORTS     23445
# 307644  2020      7             CROWN IMPORTS     23445
#
#                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0           ISTORE TRAINING OVERVIEW       REF           0.0
# 1              EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0
# 2              EMPTY 1/2 KEG (30.00)   DUNNAGE           0.0
# ...

# %%
# Displaying sales by year and item type for retail sales
sales_by_item_year = Ware_house.groupby(["ITEM TYPE", "YEAR"])["RETAIL SALES"].sum().unstack().fillna(0)

# %%
# Plotting
plt.figure(figsize=(12, 8))
sales_by_item_year.plot(kind="bar", stacked=True)
plt.legend(title="YEAR", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
# this shows the stack bar chart for the Retail sales by year with 2019 having the highest sales of 262.4797k for beer,357.0774k for liquor,13.98473k for Non alcholic,325.1128k for Wine
# the year 2018 has the lowest sales with beer having Retails sales of 35.24664k,Liqour having 57.43218k,Wine 59.20211k

# %%
print(sales_by_item_year)
# Out:
# YEAR               2017      2018       2019       2020
# ITEM TYPE
# BEER          176650.34  35246.64  262479.70   99843.85
# DUNNAGE            0.00      0.00       0.00       0.00
# KEGS               0.00      0.00       0.00       0.00
# LIQUOR        250652.84  57432.18  357077.43  137528.98
# NON-ALCOHOL     7796.66   1545.09   13984.73   10757.83
# REF              283.58     65.18     260.05      54.82
# STR_SUPPLIES     969.14    104.70    1276.51     390.53
# WINE          250382.01  59202.11  325112.78  111801.69
